# %%
# Scenario:
# We want to classify whether a restaurant order is “Large” (1) or “Small” (0) based on the number
#  of items ordered.
# - If items ≥ 3 → Large order
# - If items < 3 → Small order

import numpy as np

X = np.array([[2],[4],[3],[5]])
y = np.array([0,0,1,1])

weights = np.random.rand(1)
bias = np.random.rand(1)
learning_rate = 0.1

# step 3: Activation Function

def activation(z):
    return 1 if z >= 0 else 0

for epoch in range(10):
    print(f"Epoch {epoch+1}")
    for i in range(len(X)):
        z = np.dot(X[i], weights) + bias
        y_pred = activation(z)

        # Error
        error = y[i] - y_pred

        # Update rule
        weights += learning_rate * error * X[i]
        bias += learning_rate * error

        print(f"Input: {X[i]}, Predicted: {y_pred}, Actual: {y[i]}, Error: {error}")

print("\nFinal Weights:", weights)
print("Final Bias:", bias)

# Step 5: Test the perceptron
test_items = np.array([3, 5])
for h in test_items:
    z = np.dot(h, weights) + bias
    print(f"Items: {h}, Prediction: {activation(z)}")
# Out:
# Epoch 1
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [4], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [5], Predicted: 1, Actual: 1, Error: 0
# Epoch 2
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [4], Predicted: 0, Actual: 0, Error: 0
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [5], Predicted: 1, Actual: 1, Error: 0
# Epoch 3
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [4], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [5], Predicted: 0, Actual: 1, Error: 1
# Epoch 4
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [4], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [5], Predicted: 1, Actual: 1, Error: 0
# Epoch 5
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [4], Predicted: 0, Actual: 0, Error: 0
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [5], Predicted: 1, Actual: 1, Error: 0
# Epoch 6
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [4], Predicted: 0, Actual: 0, Error: 0
# Input: [3], Predicted: 1, Actual: 1, Error: 0
# Input: [5], Predicted: 0, Actual: 1, Error: 1
# Epoch 7
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [4], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [5], Predicted: 1, Actual: 1, Error: 0
# Epoch 8
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [4], Predicted: 0, Actual: 0, Error: 0
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [5], Predicted: 1, Actual: 1, Error: 0
# Epoch 9
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [4], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [5], Predicted: 0, Actual: 1, Error: 1
# Epoch 10
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [4], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [5], Predicted: 1, Actual: 1, Error: 0
#
# Final Weights: [0.07448649]
# Final Bias: [0.35175846]
# Items: 3, Prediction: 1
# Items: 5, Prediction: 1
